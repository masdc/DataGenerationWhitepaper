# %%
# install the dbldatagen library
# %pip install dbldatagen
# Out:
# StatementMeta(, 92a6f4af-b34d-4bb5-8681-a42c0dac83e0, 8, Finished, Available)
# Collecting dbldatagen
#   Downloading dbldatagen-0.3.5-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.3/86.3 kB 14.3 MB/s eta 0:00:00
# Installing collected packages: dbldatagen
# Successfully installed dbldatagen-0.3.5
#
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: /nfs4/pyenv-41b05168-0bfb-4f35-8d78-c95261f6474f/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
# Second Synthetic data generation example

import dbldatagen as dg #import the library
from pyspark.sql.types import IntegerType, FloatType, StringType  #use sql types to define the type of the columns.



ds = (dg.DataGenerator(spark, name="test_data_set1", rows=10,partitions=4) #10 rows of data
                            .withIdOutput() #Create an ID Column
                            .withColumn("code1", IntegerType(), minValue=100, maxValue=200) #create a column named "code1" of Integer Type, with values from 100 to 200
                            .withColumn("code2", IntegerType(), minValue=0, maxValue=10) #create a column named "code2" of Integer Type, with values from 0 to 20
                            .withColumn("code3", StringType(), values=['a', 'b', 'c']) #create a column named "code3" of String Type, with characters a,b or c as values
                            .withColumn("code4", StringType(), values=['a', 'b', 'c'], random=True) #create a column named "code4" of String Type, with String Type, with characters a,b or c as values
                            )
                            
df = ds.build() #here the data is actually generated and the DataFrame is built
df.write.mode("overwrite").format("delta").saveAsTable("Example2") #save the DataFrame as a Table in the Lakehouse
display(df.limit(10)) # show 10 rows of data
# Out:
# StatementMeta(, 92a6f4af-b34d-4bb5-8681-a42c0dac83e0, 10, Finished, Available)
# SynapseWidget(Synapse.DataFrame, b9640df6-397e-48d6-beb0-d75c3b3cd890)
